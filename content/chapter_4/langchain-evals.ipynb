# %%
# %pip install langchain langchain_openai pandas tqdm --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (0.1.1)
# Collecting langchain
#   Obtaining dependency information for langchain from https://files.pythonhosted.org/packages/54/f1/a14f29288d4b1804b81d0b9c682990b98e8c4c3dcdca7c366986f2668220/langchain-0.1.2-py3-none-any.whl.metadata
#   Downloading langchain-0.1.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: langchain_openai in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (0.0.2.post1)
# Collecting langchain_openai
#   Obtaining dependency information for langchain_openai from https://files.pythonhosted.org/packages/ff/52/fae28fb6d5bc313927166f00c50f28cc569517394c4dec40eeb75e9b1802/langchain_openai-0.0.3-py3-none-any.whl.metadata
#   Downloading langchain_openai-0.0.3-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pandas in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (2.1.4)
# Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/ee/0d/43c80cc69ad223356b61d12e488acf5f861dc833d498f43869efd871f5c9/pandas-2.2.0-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading pandas-2.2.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: tqdm in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (4.66.1)
# Requirement already satisfied: PyYAML>=5.3 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from langchain) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from langchain) (3.9.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from langchain) (0.6.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from langchain) (1.33)
# Collecting langchain-community<0.1,>=0.0.14 (from langchain)
#   Obtaining dependency information for langchain-community<0.1,>=0.0.14 from https://files.pythonhosted.org/packages/af/e5/717f5476592529d0d90fb05557349b3320ba7b78763a6e4306c45a071fd8/langchain_community-0.0.14-py3-none-any.whl.metadata
#   Downloading langchain_community-0.0.14-py3-none-any.whl.metadata (7.5 kB)
# Collecting langchain-core<0.2,>=0.1.14 (from langchain)
#   Obtaining dependency information for langchain-core<0.2,>=0.1.14 from https://files.pythonhosted.org/packages/72/d3/5965019bfbcc44d6543874d43043a35a9f2eb86bf8655789aabbcec21520/langchain_core-0.1.14-py3-none-any.whl.metadata
#   Downloading langchain_core-0.1.14-py3-none-any.whl.metadata (6.0 kB)
# Collecting langsmith<0.0.84,>=0.0.83 (from langchain)
#   Obtaining dependency information for langsmith<0.0.84,>=0.0.83 from https://files.pythonhosted.org/packages/a1/3f/0808382e9d0b504e727dbaf86f1fcbe59472cac17a205644a5f78b11c36b/langsmith-0.0.83-py3-none-any.whl.metadata
#   Downloading langsmith-0.0.83-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy<2,>=1 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from langchain) (1.24.4)
# Requirement already satisfied: pydantic<3,>=1 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from langchain) (2.5.3)
# Requirement already satisfied: requests<3,>=2 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: openai<2.0.0,>=1.6.1 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from langchain_openai) (1.8.0)
# Requirement already satisfied: tiktoken<0.6.0,>=0.5.2 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from langchain_openai) (0.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: anyio<5,>=3 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.2,>=0.1.14->langchain) (3.7.1)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.2,>=0.1.14->langchain) (23.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.6.1->langchain_openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.6.1->langchain_openai) (0.25.2)
# Requirement already satisfied: sniffio in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.6.1->langchain_openai) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.6.1->langchain_openai) (4.8.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1->langchain) (2.14.6)
# Requirement already satisfied: six>=1.5 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (1.26.17)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (2023.7.22)
# Requirement already satisfied: regex>=2022.1.18 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from tiktoken<0.6.0,>=0.5.2->langchain_openai) (2023.10.3)
# Requirement already satisfied: exceptiongroup in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.14->langchain) (1.1.0)
# Requirement already satisfied: httpcore==1.* in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.6.1->langchain_openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.6.1->langchain_openai) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/michaeltaylor/Library/Python/3.9/lib/python/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Downloading langchain-0.1.2-py3-none-any.whl (803 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.6/803.6 kB 4.7 MB/s eta 0:00:00a 0:00:01
# Downloading langchain_openai-0.0.3-py3-none-any.whl (28 kB)
# Downloading pandas-2.2.0-cp39-cp39-macosx_11_0_arm64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 4.9 MB/s eta 0:00:0000:0100:01
# Downloading langchain_community-0.0.14-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 4.9 MB/s eta 0:00:0000:0100:01
# Downloading langchain_core-0.1.14-py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.5/229.5 kB 4.3 MB/s eta 0:00:00a 0:00:01
# Downloading langsmith-0.0.83-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 2.9 MB/s eta 0:00:00
# DEPRECATION: pytorch-lightning 1.7.7 has a non-standard dependency specifier torch>=1.9.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: torchsde 0.2.5 has a non-standard dependency specifier numpy>=1.19.*; python_version >= "3.7". pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of torchsde or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: pandas, langsmith, langchain-core, langchain_openai, langchain-community, langchain
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.0.79
#     Uninstalling langsmith-0.0.79:
#       Successfully uninstalled langsmith-0.0.79
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.1.9
#     Uninstalling langchain-core-0.1.9:
#       Successfully uninstalled langchain-core-0.1.9
#   Attempting uninstall: langchain_openai
#     Found existing installation: langchain-openai 0.0.2.post1
#     Uninstalling langchain-openai-0.0.2.post1:
#       Successfully uninstalled langchain-openai-0.0.2.post1
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.0.13
#     Uninstalling langchain-community-0.0.13:
#       Successfully uninstalled langchain-community-0.0.13
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.1.1
#     Uninstalling langchain-0.1.1:
#       Successfully uninstalled langchain-0.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 3.41.0 requires websockets<12.0,>=10.0, but you have websockets 12.0 which is incompatible.
# Successfully installed langchain-0.1.2 langchain-community-0.0.14 langchain-core-0.1.14 langchain_openai-0.0.3 langsmith-0.0.83 pandas-2.2.0
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Generate Ground Truth Data with GPT-4 API
#
# Creating the known labels or ground truth data can be time consuming and expensive. You can use GPT-4 to _generate the ground truth data_ for you. This is useful for training your own models, and for evaluating the performance of other models. Then you can use these evals to test whether the open source or smaller / faster / cheaper models are performing as well as the larger / slower / more expensive models.

# %%
import pandas as pd
from tqdm import tqdm
import requests
import io

# Dataset URL:
url = "https://storage.googleapis.com/oreilly-content/transaction_data_with_expanded_descriptions.csv"

# Download the file from the URL:
downloaded_file = requests.get(url)

# Load the transactions dataset and only look at 20 transactions:
df = pd.read_csv(io.StringIO(downloaded_file.text))[:20]
df.head()
# Out:
#               Transaction Description
# 0        cash deposit at local branch
# 1        cash deposit at local branch
# 2     withdrew money for rent payment
# 3  withdrew cash for weekend expenses
# 4  purchased books from the bookstore

# %%
# Run through the dataset using GPT-4 to correctly classify the transactions
from langchain_openai.chat_models import ChatOpenAI
from langchain.output_parsers import PydanticOutputParser
from langchain_core.prompts import ChatPromptTemplate
from pydantic import BaseModel
from typing import Literal, Union

# 1. Define the model:
model = ChatOpenAI(
    model="gpt-4-1106-preview",
    model_kwargs={"response_format": {"type": "json_object"}},
)

system_prompt = """You are are an expert at analyzing bank transactions, 
you will be categorising a single transaction. 
Always return a transaction type and category: do not return None.
Format Instructions:
{format_instructions}"""

user_prompt = """Transaction Text:
{transaction}"""

# 2. Define the prompt:
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            system_prompt,
        ),
        (
            "user",
            user_prompt,
        ),
    ]
)

# 3. Define the pydantic model:
class EnrichedTransactionInformation(BaseModel):
    transaction_type: Union[
        Literal["Purchase", "Withdrawal", "Deposit", "Bill Payment", "Refund"], None
    ]
    transaction_category: Union[
        Literal["Food", "Entertainment", "Transport", "Utilities", "Rent", "Other"],
        None,
    ]


# 4. Define the output parser:
output_parser = PydanticOutputParser(pydantic_object=EnrichedTransactionInformation)

# 5. Create an LCEL chain:
chain = prompt | model | output_parser

# 6. Invoke the chain for the whole dataset:
results = []

for i, row in tqdm(df.iterrows(), total=len(df)):
    transaction = row["Transaction Description"]
    result = chain.invoke(
        {
            "transaction": transaction,
            "format_instructions": output_parser.get_format_instructions(),
        }
    )
    results.append(result)
# Out:
# 100%|██████████| 20/20 [00:53<00:00,  2.67s/it]

# %%
# 7. Add the results to the dataframe, as columns transaction type and transaction category
transaction_types = []
transaction_categories = []

for result in results:
    transaction_types.append(result.transaction_type)
    transaction_categories.append(result.transaction_category)

df["transaction_type"] = transaction_types
df["transaction_category"] = transaction_categories
df.head()
# Out:
#               Transaction Description transaction_type transaction_category
# 0        cash deposit at local branch          Deposit                Other
# 1        cash deposit at local branch          Deposit                Other
# 2     withdrew money for rent payment       Withdrawal                 Rent
# 3  withdrew cash for weekend expenses       Withdrawal                Other
# 4  purchased books from the bookstore         Purchase                Other

# %%
df.to_csv("transactions_with_enriched_data.csv", index=False)

# %% [markdown]
# ## Obtain the Accuracy of Mistral API:

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import pandas as pd
from tqdm import tqdm
import requests
import io

# Dataset URL:
url = "https://storage.googleapis.com/oreilly-content/transactions_with_enriched_data.csv"

# Download the file from the URL:
downloaded_file = requests.get(url)

# Load the transactions dataset:
df = pd.read_csv(io.StringIO(downloaded_file.text))
df.head()
# Out:
#               Transaction Description transaction_type transaction_category
# 0        cash deposit at local branch          Deposit                Other
# 1        cash deposit at local branch          Deposit                Other
# 2     withdrew money for rent payment       Withdrawal                 Rent
# 3  withdrew cash for weekend expenses       Withdrawal                Other
# 4  purchased books from the bookstore         Purchase                Other

# %%
from langchain_mistralai.chat_models import ChatMistralAI

from langchain.output_parsers import PydanticOutputParser
from langchain_core.prompts import ChatPromptTemplate
from pydantic import BaseModel
from typing import Literal, Union

import os

# 1. Define the model:
mistral_api_key = os.environ["MISTRAL_API_KEY"]

model = ChatMistralAI(model="mistral-small", mistral_api_key=mistral_api_key)

# 2. Define the prompt:
system_prompt = """You are are an expert at analyzing bank transactions, 
you will be categorising a single transaction. 
Always return a transaction type and category: do not return None.
Format Instructions:
{format_instructions}"""

user_prompt = """Transaction Text:
{transaction}"""

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            system_prompt,
        ),
        (
            "user",
            user_prompt,
        ),
    ]
)

# 3. Define the pydantic model:
class EnrichedTransactionInformation(BaseModel):
    transaction_type: Union[
        Literal["Purchase", "Withdrawal", "Deposit", "Bill Payment", "Refund"], None
    ]
    transaction_category: Union[
        Literal["Food", "Entertainment", "Transport", "Utilities", "Rent", "Other"],
        None,
    ]


# 4. Define the output parser:
output_parser = PydanticOutputParser(pydantic_object=EnrichedTransactionInformation)

# 5. Create an LCEL chain:
chain = prompt | model | output_parser

# 6. Invoke the chain for the first transaction:
transaction = df.iloc[0]["Transaction Description"]
result = chain.invoke(
        {
            "transaction": transaction,
            "format_instructions": output_parser.get_format_instructions(),
        }
    )
print(result) 
# This will often fail because Mistral puts a backslash in the JSON keys 
# i.e. "transaction\_type" instead of "transaction_type"
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/langchain/output_parsers/pydantic.py:33, in PydanticOutputParser.parse(self, text)
#      32     json_str = match.group()
# ---> 33 json_object = json.loads(json_str, strict=False)
#      34 return self.pydantic_object.parse_obj(json_object)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/__init__.py:359, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     358     kw['parse_constant'] = parse_constant
# --> 359 return cls(**kw).decode(s)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#
# JSONDecodeError: Invalid \escape: line 2 column 13 (char 14)
#
# During handling of the above exception, another exception occurred:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[67], line 57
#      55 # 6. Invoke the chain for the first transaction:
#      56 transaction = df.iloc[0]["Transaction Description"]
# ---> 57 result = chain.invoke(
#      58         {
#      59             "transaction": transaction,
#      60             "format_instructions": output_parser.get_format_instructions(),
#      61         }
#      62     )
#      63 print(result)
#      64 # This will often fail because Mistral puts a backslash in the JSON keys
#      65 # i.e. "transaction\_type" instead of "transaction_type"
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_core/runnables/base.py:2053, in RunnableSequence.invoke(self, input, config)
#    2051 try:
#    2052     for i, step in enumerate(self.steps):
# -> 2053         input = step.invoke(
#    2054             input,
#    2055             # mark each step as a child run
#    2056             patch_config(
#    2057                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    2058             ),
#    2059         )
#    2060 # finish the root run
#    2061 except BaseException as e:
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_core/output_parsers/base.py:167, in BaseOutputParser.invoke(self, input, config)
#     163 def invoke(
#     164     self, input: Union[str, BaseMessage], config: Optional[RunnableConfig] = None
#     165 ) -> T:
#     166     if isinstance(input, BaseMessage):
# --> 167         return self._call_with_config(
#     168             lambda inner_input: self.parse_result(
#     169                 [ChatGeneration(message=inner_input)]
#     170             ),
#     171             input,
#     172             config,
#     173             run_type="parser",
#     174         )
#     175     else:
#     176         return self._call_with_config(
#     177             lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     178             input,
#     179             config,
#     180             run_type="parser",
#     181         )
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_core/runnables/base.py:1246, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1242     context = copy_context()
#    1243     context.run(var_child_runnable_config.set, child_config)
#    1244     output = cast(
#    1245         Output,
# -> 1246         context.run(
#    1247             call_func_with_variable_args,
#    1248             func,  # type: ignore[arg-type]
#    1249             input,  # type: ignore[arg-type]
#    1250             config,
#    1251             run_manager,
#    1252             **kwargs,
#    1253         ),
#    1254     )
#    1255 except BaseException as e:
#    1256     run_manager.on_chain_error(e)
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_core/runnables/config.py:326, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     324 if run_manager is not None and accepts_run_manager(func):
#     325     kwargs["run_manager"] = run_manager
# --> 326 return func(input, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_core/output_parsers/base.py:168, in BaseOutputParser.invoke.<locals>.<lambda>(inner_input)
#     163 def invoke(
#     164     self, input: Union[str, BaseMessage], config: Optional[RunnableConfig] = None
#     165 ) -> T:
#     166     if isinstance(input, BaseMessage):
#     167         return self._call_with_config(
# --> 168             lambda inner_input: self.parse_result(
#     169                 [ChatGeneration(message=inner_input)]
#     170             ),
#     171             input,
#     172             config,
#     173             run_type="parser",
#     174         )
#     175     else:
#     176         return self._call_with_config(
#     177             lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     178             input,
#     179             config,
#     180             run_type="parser",
#     181         )
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_core/output_parsers/base.py:219, in BaseOutputParser.parse_result(self, result, partial)
#     206 def parse_result(self, result: List[Generation], *, partial: bool = False) -> T:
#     207     """Parse a list of candidate model Generations into a specific format.
#     208
#     209     The return value is parsed from only the first Generation in the result, which
#    (...)
#     217         Structured output.
#     218     """
# --> 219     return self.parse(result[0].text)
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain/output_parsers/pydantic.py:39, in PydanticOutputParser.parse(self, text)
#      37 name = self.pydantic_object.__name__
#      38 msg = f"Failed to parse {name} from completion {text}. Got: {e}"
# ---> 39 raise OutputParserException(msg, llm_output=text)
#
# OutputParserException: Failed to parse EnrichedTransactionInformation from completion {
# "transaction\_type": "Deposit",
# "transaction\_category": "Other"
# }. Got: Invalid \escape: line 2 column 13 (char 14)

# %%
from langchain_core.output_parsers import StrOutputParser

# 7. Define a function to try to fix and remove the backslashes:
def remove_back_slashes(string):
    cleaned_string = string.replace("\\", "") # double slash to escape the slash
    return cleaned_string

chain = prompt | model | StrOutputParser() | remove_back_slashes | output_parser

transaction = df.iloc[0]["Transaction Description"]
result = chain.invoke(
        {
            "transaction": transaction,
            "format_instructions": output_parser.get_format_instructions(),
        }
    )
print(result)
# Out:
# transaction_type='Deposit' transaction_category='Other'

# %%
# 7. Invoke the chain for the whole dataset:
results = []

for i, row in tqdm(df.iterrows(), total=len(df)):
    transaction = row["Transaction Description"]
    try:
        result = chain.invoke(
            {
                "transaction": transaction,
                "format_instructions": output_parser.get_format_instructions(),
            }
        )
    except:
        result = EnrichedTransactionInformation(
            transaction_type=None, transaction_category=None
        )
        
    results.append(result)

# 5. Add the results to the dataframe, as columns transaction type and transaction category
transaction_types = []
transaction_categories = []

for result in results:
    transaction_types.append(result.transaction_type)
    transaction_categories.append(result.transaction_category)

df["mistral_transaction_type"] = transaction_types
df["mistral_transaction_category"] = transaction_categories
df.head()
# Out:
# 100%|██████████| 20/20 [00:08<00:00,  2.32it/s]
#               Transaction Description transaction_type transaction_category  \
# 0        cash deposit at local branch          Deposit                Other
# 1        cash deposit at local branch          Deposit                Other
# 2     withdrew money for rent payment       Withdrawal                 Rent
# 3  withdrew cash for weekend expenses       Withdrawal                Other
# 4  purchased books from the bookstore         Purchase                Other
#
#   mistral_transaction_type mistral_transaction_category
# 0                  Deposit                        Other
# 1                  Deposit                        Other
# 2               Withdrawal                         Rent
# 3               Withdrawal                        Other
# 4                 Purchase                Entertainment

# %%
# 8. Evaluate answers using LangChain evaluators
from langchain.evaluation import load_evaluator

evaluator = load_evaluator("exact_match")

# loop through the dataframe and evaluate the predictions
transaction_types = []
transaction_categories = []

for i, row in tqdm(df.iterrows(), total=len(df)):
    transaction_type = row["transaction_type"]
    predicted_transaction_type = row["mistral_transaction_type"]
    transaction_category = row["transaction_category"]
    predicted_transaction_category = row["mistral_transaction_category"]

    transaction_type_score = evaluator.evaluate_strings(
        prediction=predicted_transaction_type,
        reference=transaction_type,
    )

    transaction_category_score = evaluator.evaluate_strings(
        prediction=predicted_transaction_category,
        reference=transaction_category,
    )

    transaction_types.append(transaction_type_score)
    transaction_categories.append(transaction_category_score)
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 11329.83it/s]

# %%
accuracy_score = 0

for transaction_type_score, transaction_category_score in zip(
    transaction_types, transaction_categories
):
    accuracy_score += transaction_type_score['score'] + transaction_category_score['score']

accuracy_score = accuracy_score / (len(transaction_types) * 2)
print(f"Accuracy score: {accuracy_score}")
# Out:
# Accuracy score: 0.775

# %% [markdown]
# ## Compare Mistral API with GPT-3.5 API:

# %%
from langchain_openai.chat_models import ChatOpenAI

# 1. Define the model:
model = ChatOpenAI(
    model="gpt-3.5-turbo-1106",
    model_kwargs={"response_format": {"type": "json_object"}},
)

chain = prompt | model | output_parser

# 2. Invoke the chain for the first transaction:
transaction = df.iloc[0]["Transaction Description"]
result = chain.invoke(
        {
            "transaction": transaction,
            "format_instructions": output_parser.get_format_instructions(),
        }
    )
print(result)
# Out:
# transaction_type='Deposit' transaction_category='Other'

# %%
# 3. Invoke the chain for the whole dataset:
results = []

for i, row in tqdm(df.iterrows(), total=len(df)):
    transaction = row["Transaction Description"]
    try:
        result = chain.invoke(
            {
                "transaction": transaction,
                "format_instructions": output_parser.get_format_instructions(),
            }
        )
    except:
        result = EnrichedTransactionInformation(
            transaction_type=None, transaction_category=None
        )
    
    results.append(result)

# 4. Add the results to the dataframe, as columns transaction type and transaction category
transaction_types = []
transaction_categories = []

for result in results:
    transaction_types.append(result.transaction_type)
    transaction_categories.append(result.transaction_category)

df["gpt3.5_transaction_type"] = transaction_types
df["gpt3.5_transaction_category"] = transaction_categories

df.head()
# Out:
# 100%|██████████| 20/20 [00:42<00:00,  2.14s/it]
#               Transaction Description transaction_type transaction_category  \
# 0        cash deposit at local branch          Deposit                Other
# 1        cash deposit at local branch          Deposit                Other
# 2     withdrew money for rent payment       Withdrawal                 Rent
# 3  withdrew cash for weekend expenses       Withdrawal                Other
# 4  purchased books from the bookstore         Purchase                Other
#
#   mistral_transaction_type mistral_transaction_category  \
# 0                  Deposit                        Other
# 1                  Deposit                        Other
# 2               Withdrawal                         Rent
# 3               Withdrawal                        Other
# 4                 Purchase                Entertainment
#
#   gpt3.5_transaction_type gpt3.5_transaction_category
# 0                 Deposit                       Other
# 1                 Deposit                       Other
# 2              Withdrawal                        Rent
# 3              Withdrawal               Entertainment
# 4                Purchase               Entertainment

# %%
# loop through the dataframe and evaluate the predictions
transaction_types = []
transaction_categories = []

for i, row in tqdm(df.iterrows(), total=len(df)):
    transaction_type = row["transaction_type"]
    predicted_transaction_type = row["gpt3.5_transaction_type"]
    transaction_category = row["transaction_category"]
    predicted_transaction_category = row["gpt3.5_transaction_category"]

    transaction_type_score = evaluator.evaluate_strings(
        prediction=predicted_transaction_type,
        reference=transaction_type,
    )

    transaction_category_score = evaluator.evaluate_strings(
        prediction=predicted_transaction_category,
        reference=transaction_category,
    )

    transaction_types.append(transaction_type_score)
    transaction_categories.append(transaction_category_score)

accuracy_score = 0

for transaction_type_score, transaction_category_score in zip(
    transaction_types, transaction_categories
):
    accuracy_score += transaction_type_score['score'] + transaction_category_score['score']

accuracy_score = accuracy_score / (len(transaction_types) * 2)
print(f"Accuracy score: {accuracy_score}")
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 13606.83it/s]
# Accuracy score: 0.75

# %%
# Pairwise comparison between GPT-4 and Mistral
from langchain.evaluation import load_evaluator
evaluator = load_evaluator("labeled_pairwise_string")

row = df.iloc[0]
transaction = row["Transaction Description"]
gpt3pt5_category = row["gpt3.5_transaction_category"]
gpt3pt5_type = row["gpt3.5_transaction_type"]
mistral_category = row["mistral_transaction_category"]
mistral_type = row["mistral_transaction_type"]
reference_category = row["transaction_category"]
reference_type = row["transaction_type"]

# put the data into JSON format for the evaluator
gpt3pt5_data = f"""{{
    "transaction_category": "{gpt3pt5_category}",
    "transaction_type": "{gpt3pt5_type}"
}}"""

mistral_data = f"""{{
    "transaction_category": "{mistral_category}",
    "transaction_type": "{mistral_type}"
}}"""

reference_data = f"""{{
    "transaction_category": "{reference_category}",
    "transaction_type": "{reference_type}"
}}"""

# set up the prompt input for context for the evaluator
input_prompt = """You are are an expert at analyzing bank transactions, 
you will be categorising a single transaction. 
Always return a transaction type and category: do not return None.
Format Instructions:
{format_instructions}
Transaction Text:
{transaction}
"""

evaluator.evaluate_string_pairs(
    prediction=gpt3pt5_data,
    prediction_b=mistral_data,
    input=input_prompt.format(
        format_instructions=output_parser.get_format_instructions(),
        transaction=transaction),
    reference=reference_data,
)
# Out:
# {'reasoning': 'Both Assistant A and Assistant B provided the exact same response to the user\'s question. Their responses are both helpful, relevant, correct, and demonstrate depth of thought. They both correctly identified the transaction type as "Deposit" and the transaction category as "Other" based on the transaction text provided by the user. Both responses are also well-formatted according to the JSON schema provided by the user. Therefore, it\'s a tie between the two assistants. \n\nFinal Verdict: [[C]]',
#  'value': None,
#  'score': 0.5}

# %%
# run through the whole dataset and add the pairwise comparison scores to the dataframe
pairwise_scores = []

for i, row in tqdm(df.iterrows(), total=len(df)):
    transaction = row["Transaction Description"]
    gpt3pt5_category = row["gpt3.5_transaction_category"]
    gpt3pt5_type = row["gpt3.5_transaction_type"]
    mistral_category = row["mistral_transaction_category"]
    mistral_type = row["mistral_transaction_type"]
    reference_category = row["transaction_category"]
    reference_type = row["transaction_type"]

    # put the data into JSON format for the evaluator
    gpt3pt5_data = f"""{{
        "transaction_category": "{gpt3pt5_category}",
        "transaction_type": "{gpt3pt5_type}"
    }}"""

    mistral_data = f"""{{
        "transaction_category": "{mistral_category}",
        "transaction_type": "{mistral_type}"
    }}"""

    reference_data = f"""{{
        "transaction_category": "{reference_category}",
        "transaction_type": "{reference_type}"
    }}"""

    # set up the prompt input for context for the evaluator
    input_prompt = """You are are an expert at analyzing bank transactions, 
    you will be categorising a single transaction. 
    Always return a transaction type and category: do not return None.
    Format Instructions:
    {format_instructions}
    Transaction Text:
    {transaction}
    """

    pairwise = evaluator.evaluate_string_pairs(
        prediction=gpt3pt5_data,
        prediction_b=mistral_data,
        input=input_prompt.format(
            format_instructions=output_parser.get_format_instructions(),
            transaction=transaction),
        reference=reference_data,
    )
    pairwise_scores.append(pairwise)

# add the pairwise scores to the dataframe
reasoning = []
scores = []

for score in pairwise_scores:
    reasoning.append(score['reasoning'])
    scores.append(score['score'])

df['pairwise_reasoning'] = reasoning
df['pairwise_score'] = scores

df.head()
# Out:
# 100%|██████████| 20/20 [04:08<00:00, 12.43s/it]
#               Transaction Description transaction_type transaction_category  \
# 0        cash deposit at local branch          Deposit                Other
# 1        cash deposit at local branch          Deposit                Other
# 2     withdrew money for rent payment       Withdrawal                 Rent
# 3  withdrew cash for weekend expenses       Withdrawal                Other
# 4  purchased books from the bookstore         Purchase                Other
#
#   mistral_transaction_type mistral_transaction_category  \
# 0                  Deposit                        Other
# 1                  Deposit                        Other
# 2               Withdrawal                         Rent
# 3               Withdrawal                        Other
# 4                 Purchase                Entertainment
#
#   gpt3.5_transaction_type gpt3.5_transaction_category  \
# 0                 Deposit                       Other
# 1                 Deposit                       Other
# 2              Withdrawal                        Rent
# 3              Withdrawal               Entertainment
# 4                Purchase               Entertainment
#
#                                   pairwise_reasoning  pairwise_score
# 0  Both Assistant A and Assistant B provided the ...             0.5
# 1  Both Assistant A and Assistant B provided the ...             0.5
# 2  Both Assistant A and Assistant B provided the ...             0.5
# 3  Both Assistant A and Assistant B provided resp...             0.0
# 4  Both Assistant A and Assistant B provided the ...             0.5

# %%
row = df.iloc[3]
print("Transaction: ", row['Transaction Description'])
print()
print("Reference:", row['transaction_type'], row['transaction_category'])
print("GPT-3.5 (A):", row['gpt3.5_transaction_type'], row['gpt3.5_transaction_category'])
print("Mistral (B):", row['mistral_transaction_type'], row['mistral_transaction_category'])

print()
print(row['pairwise_reasoning'])
# Out:
# Transaction:  withdrew cash for weekend expenses
#
# Reference: Withdrawal Other
# GPT-3.5 (A): Withdrawal Entertainment
# Mistral (B): Withdrawal Other
#
# Both Assistant A and Assistant B provided responses that are helpful, relevant, and correct. They both followed the user's instructions and provided a transaction type and category in the correct JSON format. However, the difference lies in the transaction category they chose. Assistant A categorized the transaction as "Entertainment", while Assistant B categorized it as "Other". Given the transaction text "withdrew cash for weekend expenses", it's not explicitly clear what the cash will be used for. It could be for entertainment, but it could also be for other expenses. Therefore, Assistant B's response is more accurate as it doesn't make assumptions about the nature of the weekend expenses. Hence, Assistant B's response is better.
#
# Final Verdict: [[B]]
